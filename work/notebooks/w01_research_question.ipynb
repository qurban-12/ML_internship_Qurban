# %% [markdown]
# <a href="https://colab.research.google.com/github/qurban-12/ML_internship_Qurban/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/qurban-12/ML_internship_Qurban/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because I want to identify which pages should be reviewed first by a content team. The goal is not to automatically decide what to change, but to create a ranked list that helps people focus their limited review time. The starter dataset contains page-level performance and content information, which makes this lane a practical starting point.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### The question
#
# **Decision:** Which pages should a content team review first?
#
# **Who acts:** Content or SEO team members can use the ranked results to decide which pages need attention.
#
# **Action:** A reviewer can inspect the highest-ranked pages and decide whether to refresh, expand, protect, prune, or monitor them.
#
# **Cost of a wrong recommendation:** The team may waste limited review time on a page that does not need attention, or miss a page that deserved review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !git clone https://github.com/qurban-12/ML_internship_Qurban.git
# Out:
# fatal: destination path 'ML_internship_Qurban' already exists and is not an empty directory.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Quick look at the data
#
# The starter dataset contains **30,000 pages**. About **54.2% of the pages** are labeled with a downward trend, and the **median content age is 236 days**. These numbers suggest that there is enough page-level performance and content-age information to investigate which pages may deserve review first. This makes Refresh / Content Opportunity Scoring a useful lane to explore further.

# %%
import pandas as pd

df = pd.read_csv("ML_internship_Qurban/data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Declining rate:", round((df["trend_direction"] == "down").mean(), 3))
print("Median content age (days):", df["content_age_days"].median())
# Out:
# Number of rows: 30000
# Declining rate: 0.542
# Median content age (days): 236.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### What I can and can't claim
#
# I can use the available data to identify observed patterns and create a directional ranking of pages that may deserve review. The output will be used as decision-support for content and SEO teams, not as an automatic decision.
#
# I cannot claim that the ranking will cause traffic or performance to improve. I also cannot claim that the data explains Google's ranking algorithm or predict what Google will do. Any recommendations will need to be reviewed by a person and validated using appropriate holdout data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
